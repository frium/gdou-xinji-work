# %% [markdown]
# # Python实验报告3

# %% [raw]
# 班级：          姓名：           学号：

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 要求：
# 1. 在文件开头部分填写自己的信息；
# 2. 在每个题下方的代码块中书写该题的代码，并运行出结果；
# 3. 在2节课的时间内完成前7个题；打印为pdf文件并提交，文件名改为“Python实验3+班级姓名.pdf”。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 一、实验目的：
#
# - 掌握元组、字典、集合的创建及操作方法、字典推导式；
# - 掌握可迭代对象的一些常用内置函数：map(), zip(), enumerate()
# - 掌握字符串输出的一些格式；
# - 能合理使用Python组合数据类型解决一些简单的实际问题。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 二、实验内容（在各题后书写程序和运行结果）

# %% [raw]
# 1. 填充题：目前，我们接触到的Python数据类型有：
#  A.数值、 B.字符串、 C.range对象、  D.列表、 E.元组、 F.字典、 G.集合。
# (1) 上述的数据类型中，可变数据类型有（    ）；
# (2) 上述的数据类型中，哪些可以使用双向索引访问（    ）；
# (3) 上述的数据类型中，哪些可以作为字典的键（    ）；
# (4) 上述的数据类型中，哪些是可迭代对象（    ）。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 2. 已知下列的两个元组，试产生一个字典，键来自元组1，值来自元组2的对应位置。

# %%
day = ('Sun', 'Mon', 'Tues', 'Wed', 'Thur', 'Fri', 'Sat') 
index = ('日','一','二','三','四','五','六')

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 3. 对下列的一个16位随机正整数，选出是奇数的各位数字，放到一个列表中。要求使用`map()`。

# %%
from random import randint

num = randint(1e15,1e16)
print(num)
# Out:
# 5307768986344615

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 4. 已知某六人宿舍目前有四个同学，他们是小陈, 小何, 小梁, 小谢，他们分别选了4号床, 3号床, 5号床, 2号床。
# （1）以姓名为键，床位为值建立一个字典stu1。
# （2）后来又来了小王和小李，他们分别选了1号床和6号床，且小何和小梁换了床位，对字典stu1更新信息。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 5. 已知某宿舍同学小陈、小何、小梁、小谢、小王、小李的学号为202311921123～202311921128。以姓名为键，学号为值，创建一个字典stu2。尝试多种方法创建。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 6. 已知问题5中创建的字典stu2，将其各项的键值对颠倒，以键为值、以值为键，产生另一个字典stu3。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 7. 某商场促销活动，总价低于100元内不打折，[100,200)打9折，[200,500)打8.5折，[500,1000)打8折，1000以上打7.5折。现有顾客数人，他们购买商品总价分别为[355, 704, 256, 883, 1521, 197, 556]，请以字典形式保存商品总价和实际收款数，并按格式输出："总价为s的商品，打折后为t"，精确到小数点后2位。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 8. （选做题）使用random模块的randint函数产生[1,10]上的100个随机整数，然后用一个字典记录各不同的数字及其出现次数。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 9. （选做题）对问题4中的字典stu1中的元素逐个输出，
#     (1)要求每行输出一个人名及其床位，中间用":"分隔。
#     (2)在(1)的基础上要求按床位从小到大的顺序输出。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 10. （选做题）问题4和问题5中的同学是同一批人，试将stu1和stu2合并成1个字典stu4，以姓名为键，值为元组，包含该生的学号和床位。

# %% [markdown]
# <font face='kaiti' size=5 style='line-height:1.5'>
#
# 11. （选做题）从问题9中的字典stu4出发，将其键和值重新组合，以床号为键，姓名和学号组成的元组为值，创建新字典stu5。
